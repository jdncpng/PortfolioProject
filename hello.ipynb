# %%
print("hello world! Good morning")
# Out:
# hello world!

# %%
import pandas

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Jaeden Capinig\Documents\PortfolioProject\qog_perceive_survey17_cleaned.csv')

cols = ['country', 'd1', 'd2recoded', 'd3', 'd5recoded', 'd7b', 'q1_2', 'q1_4', 'q2', 'q4']

for col in cols:
    print(f"=== df['{col}'].value_counts() ===")
    print(df[col].value_counts())
    print()

# %%
print("Wieder da!")
